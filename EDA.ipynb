# %%
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2 as ps

# %%
df = pd.read_csv('e_commerce_shopper_behaviour_and_lifestyle.csv', sep=',')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    user_id  age  gender  country urban_rural  income_level employment_status  \
# 0        1   56  Female  Germany    Suburban         90860     Self-employed
# 1        2   69    Male    Japan    Suburban         35423        Unemployed
# 2        3   46  Female    India       Urban         21467     Self-employed
# 3        4   32    Male   Canada       Urban         41770     Self-employed
# 4        5   60  Female    Japan       Urban        183882          Employed
#
#     education_level relationship_status  has_children  household_size  \
# 0  Associate Degree              Single             0               5
# 1          Bachelor              Single             1               2
# 2  Associate Degree             Married             1               6
# 3          Bachelor             Widowed             0               4
# 4  Associate Degree             Widowed             1               9
#
#     occupation ethnicity language_preference device_type  weekly_purchases  \
# ...

# %%
df.to_csv('shopper_behavior.csv', index=False)

# %%
len(df)
# Out:
# 1000000

# %%
total_missing = df.isnull().sum().sum()
print(total_missing)
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# user_id                            0
# age                                0
# gender                             0
# country                            0
# urban_rural                        0
# income_level                       0
# employment_status                  0
# education_level                    0
# relationship_status                0
# has_children                       0
# household_size                     0
# occupation                         0
# ethnicity                          0
# language_preference                0
# device_type                        0
# weekly_purchases                   0
# monthly_spend                      0
# cart_abandonment_rate              0
# review_writing_frequency           0
# average_order_value                0
# preferred_payment_method           0
# coupon_usage_frequency             0
# loyalty_program_member             0
# referral_count                     0
# product_category_preference        0
# ...

# %%
df.isnull().sum()
total_missing = df.isnull().sum().sum()
print(total_missing)

# %%
df_reduzido = df.iloc[:300000,:]
df_reduzido.head()
# Out:
#    user_id  age  gender  country urban_rural  income_level employment_status  \
# 0        1   56  Female  Germany    Suburban         90860     Self-employed
# 1        2   69    Male    Japan    Suburban         35423        Unemployed
# 2        3   46  Female    India       Urban         21467     Self-employed
# 3        4   32    Male   Canada       Urban         41770     Self-employed
# 4        5   60  Female    Japan       Urban        183882          Employed
#
#     education_level relationship_status  has_children  household_size  \
# 0  Associate Degree              Single             0               5
# 1          Bachelor              Single             1               2
# 2  Associate Degree             Married             1               6
# 3          Bachelor             Widowed             0               4
# 4  Associate Degree             Widowed             1               9
#
#     occupation ethnicity language_preference device_type  weekly_purchases  \
# ...

# %%
len(df_reduzido)
# Out:
# 300000

# %%
df_reduzido.to_csv('shopper_behavior.csv', index=False)

# %%
teste = pd.read_csv('shopper_behavior.csv',sep=',')
teste.head()
# Out:
#    user_id  age  gender  country urban_rural  income_level employment_status  \
# 0        1   56  Female  Germany    Suburban         90860     Self-employed
# 1        2   69    Male    Japan    Suburban         35423        Unemployed
# 2        3   46  Female    India       Urban         21467     Self-employed
# 3        4   32    Male   Canada       Urban         41770     Self-employed
# 4        5   60  Female    Japan       Urban        183882          Employed
#
#     education_level relationship_status  has_children  household_size  \
# 0  Associate Degree              Single             0               5
# 1          Bachelor              Single             1               2
# 2  Associate Degree             Married             1               6
# 3          Bachelor             Widowed             0               4
# 4  Associate Degree             Widowed             1               9
#
#     occupation ethnicity language_preference device_type  weekly_purchases  \
# ...

# %%
len(teste)
# Out:
# 300000
